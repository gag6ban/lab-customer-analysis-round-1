# %% [markdown]
# # Round 1

# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
file1.shape
file2.shape
file3.shape
# Out:
# (7070, 11)

# %%
cols = []
for column in file1.columns:
    cols.append(column.lower())
file1.columns = cols
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols = []
for column in file2.columns:
    cols.append(column.lower())
file2.columns = cols
file2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
cols = []
for column in file3.columns:
    cols.append(column.lower())
file3.columns = cols
file3
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
column_names = file1.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
column_names = file2.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
column_names = file3.columns
column_names
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file2 = file2[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
file2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
file3 = file3.rename(columns={'state':'st'})
file3.columns
# Out:
# Index(['customer', 'st', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
column_names = file3.columns
column_names
# Out:
# Index(['customer', 'st', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file3 = file3[['customer', 'st', 'gender', 'education', 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class', 'total claim amount']]
file3
# Out:
#      customer          st gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
file1.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
file2.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                         int64
# monthly premium auto           int64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
file3.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                         int64
# monthly premium auto           int64
# number of open complaints      int64
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# dtype: object

# %%
file1 = file1.drop(['number of open complaints' ], axis =1)
column_names = file1.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
file3 = file3.drop(['education'], axis =1)
column_names = file2.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file3 = file3.drop(['number of open complaints' ], axis =1)
column_names = file3.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'customer lifetime value', 'income',
#        'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
file2 = file2.drop(['number of open complaints' ], axis =1)
column_names = file2.columns
column_names
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'policy type', 'vehicle class',
#        'total claim amount'],
#       dtype='object')

# %%
file1['customer lifetime value'] = file1['customer lifetime value'].str.replace('%', '')

# %%
file2['customer lifetime value'] = file2['customer lifetime value'].str.replace('%', '')

# %%
file1['customer lifetime value'] = pd.to_numeric(file1['customer lifetime value'], errors='coerce')

# %%
file2['customer lifetime value'] = pd.to_numeric(file2['customer lifetime value'], errors='coerce')

# %%
file3['customer lifetime value'] = pd.to_numeric(file3['customer lifetime value'], errors='coerce')

# %%
file1['customer lifetime value'] = file1['customer lifetime value']/100

# %%
file2['customer lifetime value'] = file2['customer lifetime value']/100

# %%
file1.shape
file2.shape
file3.shape
# Out:
# (7070, 9)

# %%
file2.shape
# Out:
# (996, 10)

# %%
file3.shape
# Out:
# (7070, 9)

# %% [markdown]
# # Concatenate all 3 files

# %%
data = pd.concat([file1, file2, file3], axis=0)

data
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M                   NaN
# 7066  PK87824  California      F                   NaN
# 7067  TD14365  California      M                   NaN
# 7068  UP19263  California      M                   NaN
# 7069  Y167826  California      M                   NaN
#
#       customer lifetime value   income  monthly premium auto     policy type  \
# 0                         NaN      0.0                1000.0   Personal Auto
# 1                 6979.535900      0.0                  94.0   Personal Auto
# ...

# %% [markdown]
# # Look at numerical and categorical data

# %%
data.dtypes

# Numerical: All columns labeled 'float64'

# Categorical: All columns labeled 'object
# Out:
# customer                    object
# st                          object
# gender                      object
# education                   object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# dtype: object

# %%
data = data.drop_duplicates()

data.shape
# Out:
# (9135, 10)

# %%
data_with_income = data[data['income']>0]

data_with_income
# Out:
#      customer          st gender             education  \
# 2     AI49188      Nevada      F              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# 6     XZ87318      Oregon      F               College
# 8     DY87989      Oregon      M              Bachelor
# ...       ...         ...    ...                   ...
# 7063  TF56202  California      M                   NaN
# 7064  YM19146  California      F                   NaN
# 7065  LA72316  California      M                   NaN
# 7066  PK87824  California      F                   NaN
# 7068  UP19263  California      M                   NaN
#
#       customer lifetime value   income  monthly premium auto     policy type  \
# 2                12887.431700  48767.0                 108.0   Personal Auto
# 4                 5363.076500  36357.0                  68.0   Personal Auto
# ...
